# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('experimentation.csv',sep=";")

# %%
data
# Out:
#       Number of agent  root branch  max-arguments-per-branch   rand-seed  \
# 0                  10            5                        10         453
# 1                  10            5                        10         453
# 2                  10            5                        10         453
# 3                  10            5                        10         453
# 4                   2            2                         2           1
# ...               ...          ...                       ...         ...
# 3586                2           16                       862           1
# 3587                2           16                       872           1
# 3588                2           16                       882           1
# 3589                2           16                       892           1
# 3590                2           16                       902           1
#
#        max-arguments-at-once   number of round   runtime  freq-deep-arg  \
# 0                          2                 4  0.012026        19:28:3
# 1                          2                 4  0.011938        19:28:3
# 2                          2                 4  0.017368        19:28:3
# 3                          2                 4  0.017104        19:28:3
# 4                          1                 2  0.000292            3:3
# ...                      ...               ...       ...            ...
# 3586                       1                 5  0.111257            3:9
# 3587                       1                 5  0.113256            3:9
# 3588                       1                 5  0.134163            3:9
# 3589                       1                 5  0.179188            3:9
# 3590                       1                 5  0.134185            3:9
#
#        issue value   std_goal_issues_values   std_from_final_issue_value
# 0         0.300374                 0.043341                     0.043369
# 1         0.300374                 0.043341                     0.043369
# 2         0.300374                 0.043341                     0.043369
# 3         0.300374                 0.043341                     0.043369
# 4         0.400000                 0.033333                     0.047140
# ...            ...                      ...                          ...
# 3586      0.100000                 0.002581                     0.002924
# 3587      0.100000                 0.002581                     0.002924
# 3588      0.100000                 0.002581                     0.002924
# 3589      0.100000                 0.002581                     0.002924
# 3590      0.100000                 0.002581                     0.002924
#
# [3591 rows x 11 columns]

# %%
data = data.iloc[:,:7]

# %%
data
# Out:
#       Number of agent  root branch  max-arguments-per-branch   rand-seed  \
# 0                  10            5                        10         453
# 1                  10            5                        10         453
# 2                  10            5                        10         453
# 3                  10            5                        10         453
# 4                   2            2                         2           1
# ...               ...          ...                       ...         ...
# 2721                2            8                       232           1
# 2722                2            8                       242           1
# 2723                2            8                       252           1
# 2724                2            8                       262           1
# 2725                2            8                       272           1
#
#        max-arguments-at-once   number of round   runtime
# 0                          2                 4  0.012026
# 1                          2                 4  0.011938
# 2                          2                 4  0.017368
# 3                          2                 4  0.017104
# 4                          1                 2  0.000292
# ...                      ...               ...       ...
# 2721                       1                 3  0.021991
# 2722                       1                 3  0.023013
# 2723                       1                 3  0.019048
# 2724                       1                15  0.046386
# 2725                       1                15  0.045226
#
# [2726 rows x 7 columns]

# %%
data.shape
# Out:
# (2726, 7)

# %%
corr_matrix = data.corr()

# Visualiser la matrice de corrélation
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Corrélation entre les variables')
plt.show()

# %%
data.hist(figsize=(10,10))
plt.show()

# %%
sns.pairplot(data)
